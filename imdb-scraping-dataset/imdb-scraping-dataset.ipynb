# %%
Hay que construir de un dataset a partir de un proceso automático que nos permita recopilar información de la base de datos de películas del sitio web de IMDB.

El dataset resultante podremos utilizarlo para entrenar un modelo de aprendizaje automático que nos permita realizar algunas predicciones sobre los datos.

Tendremos que desarrollar una aplicación que sea capaz de analizar el sitio web de IMDB automáticamente. En el entorno de Python existen varias alternativas, aunque nosotros vamos a utilizar el framework de Scrapy para ello. Se trata de una potente herramienta que nos permitirá explorar los sitios web de manera programática utilizando para ello expresiones XPath o selectores CSS.

Podéis usar la información que hay al respecto en la documentación de este tema, en este curso de OpenWebinars y en estos vídeos (contraseña UCLMIABD-2022):

https://vimeo.com/645966008
https://vimeo.com/645972721
https://vimeo.com/645972998
https://vimeo.com/645973056
https://vimeo.com/645973112
